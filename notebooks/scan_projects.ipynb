# %% [markdown]
# # Project Database Scanner
#
# This notebook scans ~/git/active and populates the project database.

# %%
# Setup - load environment and initialize database
import os
from pathlib import Path
from dotenv import load_dotenv

# %%
# Load .env from project root
# project_root = Path.cwd().parent
# env_file = project_root / ".env"
load_dotenv()

print(f"DATABASE_PATH: {os.getenv('DATABASE_PATH')}")
# Out:
# DATABASE_PATH: /home/romilly/git/active/project-database/data/projects.sqlite

# %%
# Initialize database
from project_database.database import init_database, get_session
from project_database.models import Project

init_database()
print("Database initialized successfully!")
# Out:
# Database initialized successfully!

# %%
# Check current database state
session = get_session()
count = session.query(Project).count()
print(f"Current projects in database: {count}")
session.close()
# Out:
# Current projects in database: 322

# %%
# Scan ~/git/active directory
from project_database.scanner import populate_database

projects_dir = Path.home() / "git" / "active"
print(f"Scanning: {projects_dir}")

# This will take a moment...
populate_database(projects_dir)

print("\nScan complete!")
# Out:
# Scanning: /home/romilly/git/active
#
# Scan complete!

# %%
# Show statistics
session = get_session()

total = session.query(Project).count()
with_readme = session.query(Project).filter(Project.readme_path.isnot(None)).count()
with_logseq = session.query(Project).filter(Project.logseq_page.isnot(None)).count()
with_github = session.query(Project).filter(Project.github_url.isnot(None)).count()

print(f"Total projects: {total}")
print(f"Projects with README: {with_readme}")
print(f"Projects with Logseq page: {with_logseq}")
print(f"Projects with GitHub URL: {with_github}")

session.close()
# Out:
# Total projects: 322
# Projects with README: 154
# Projects with Logseq page: 177
# Projects with GitHub URL: 131

# %%
# Show sample projects with GitHub URLs
session = get_session()

github_projects = session.query(Project).filter(Project.github_url.isnot(None)).limit(10).all()

print("Sample projects with GitHub URLs:\n")
for p in github_projects:
    print(f"  {p.name}")
    print(f"    GitHub: {p.github_url}")
    if p.logseq_page:
        print(f"    Logseq: {p.logseq_page}")
    print()

session.close()
# Out:
# Sample projects with GitHub URLs:
#
#   servus-orig
#     GitHub: https://github.com/romilly/servus
#
#   redpajama.cpp
#     GitHub: https://github.com/romilly/redpajama.cpp
#
#   github_star_tracker
#     GitHub: https://github.com/romilly/github_star_tracker
#
#   ii-microservice
#     GitHub: https://github.com/romilly/ii-microservice
#     Logseq: project/ii-microservice
#
#   oxo
#     GitHub: https://github.com/romilly/oxo
#
#   mooc-talk
#     GitHub: https://github.com/romilly/mooc-talk
#
#   pimoroni-booklet
#     GitHub: https://github.com/romilly/pimoroni-booklet
#
#   P3SE
#     GitHub: https://github.com/romilly/P3SE
#     Logseq: P3SE
#
#   LLMs-from-scratch
#     GitHub: https://github.com/romilly/LLMs-from-scratch
#
#   TIL-private
#     GitHub: https://github.com/romilly/TIL-private
#     Logseq: project/TIL-private

# %%
# Query projects by name
session = get_session()

search_term = "project-database"  # Change this to search for different projects
results = session.query(Project).filter(Project.name.like(f"%{search_term}%")).all()

print(f"Projects matching '{search_term}':\n")
for p in results:
    print(f"  {p.name}")
    print(f"    Path: {p.path}")
    print(f"    README: {p.readme_path or 'None'}")
    print(f"    Logseq: {p.logseq_page or 'None'}")
    print(f"    GitHub: {p.github_url or 'None'}")
    print()

session.close()

# %% [markdown]
# ## Optional: View all projects
#
# Uncomment and run the cell below to see all projects (may be a long list!)

# %%
session = get_session()
all_projects = session.query(Project).order_by(Project.name).all()

for p in all_projects:
    print(f"{p.name}: {p.readme_path or 'no README'} {p.github_url or 'no GitHub'}")

session.close()
# Out:
# .claude: no README no GitHub
# AutoPair: no README no GitHub
# BASB: /home/romilly/git/active/BASB/README.md no GitHub
# BCPNN: /home/romilly/git/active/BCPNN/README.md https://github.com/romilly/BCPNN
# ChatGPT-Micro-Cap-Experiment: /home/romilly/git/active/ChatGPT-Micro-Cap-Experiment/README.md https://github.com/romilly/ChatGPT-Micro-Cap-Experiment
# ComfyUI: /home/romilly/git/active/ComfyUI/README.md https://github.com/comfyanonymous/ComfyUI
# Emerge-Education-Pitch: no README no GitHub
# HelixNet-experiments: no README no GitHub
# LLMs-from-scratch: /home/romilly/git/active/LLMs-from-scratch/README.md https://github.com/romilly/LLMs-from-scratch
# Lanchain-AutoGPT: /home/romilly/git/active/Lanchain-AutoGPT/README.md no GitHub
# LinkedIn: no README no GitHub
# LlamaFarmer: /home/romilly/git/active/LlamaFarmer/README.md no GitHub
# LlamaParse-experiments: no README no GitHub
# MinerU: /home/romilly/git/active/MinerU/README.md https://github.com/romilly/MinerU
# OPRO: /home/romilly/git/active/OPRO/README.md no GitHub
# OpenAgents-spike: /home/romilly/git/active/OpenAgents-spike/README.md https://github.com/xlang-ai/OpenAgents
# P3SE: /home/romilly/git/active/P3SE/README.md https://github.com/romilly/P3SE
# PicoPyForth: /home/romilly/git/active/PicoPyForth/README.md https://github.com/romilly/PicoPyForth
# PriceHistory: /home/romilly/git/active/PriceHistory/README.md https://github.com/romilly/PriceHistory
# PyForth: /home/romilly/git/active/PyForth/README.md https://github.com/romilly/PyForth
# PyMuPDF-spike: no README no GitHub
# RareBlog: /home/romilly/git/active/RareBlog/README.md https://github.com/romilly/RareBlog
# StockMonitor: /home/romilly/git/active/StockMonitor/README.md https://github.com/romilly/StockMonitor
# TIL-private: no README https://github.com/romilly/TIL-private
# TIL-this-about-AI-Agents: /home/romilly/git/active/TIL-this-about-AI-Agents/README.md https://github.com/romilly/TIL-this-about-AI-Agents
# Thinking-Skills: no README no GitHub
# accelerate_spike: /home/romilly/git/active/accelerate_spike/README.md no GitHub
# agent-scope-experiments: no README no GitHub
# ai-coda: /home/romilly/git/active/ai-coda/README.md no GitHub
# aide-spike: no README no GitHub
# alphavantage-access: no README no GitHub
# anns: /home/romilly/git/active/anns/README.md https://github.com/romilly/anns
# anthropic-agents: no README no GitHub
# applied-data-science-with-python: /home/romilly/git/active/applied-data-science-with-python/README.md no GitHub
# arc-prize: no README https://github.com/romilly/arc-prize
# archicortex: /home/romilly/git/active/archicortex/README.md https://github.com/romilly/archicortex
# articles: no README https://github.com/romilly/articles
# arxiv-dspy: no README no GitHub
# arxiv-librarian: /home/romilly/git/active/arxiv-librarian/README.md https://github.com/romilly/arxiv-librarian
# arxiv-librarian (copy): /home/romilly/git/active/arxiv-librarian (copy)/README.md https://github.com/romilly/arxiv-librarian
# autogen-experiments: /home/romilly/git/active/autogen-experiments/README.md no GitHub
# awq-spike: no README no GitHub
# baby-agi-spike: no README no GitHub
# books: /home/romilly/git/active/books/README.md https://github.com/romilly/books
# boxes: /home/romilly/git/active/boxes/README.md https://github.com/romilly/boxes
# brain-levers: /home/romilly/git/active/brain-levers/README.md https://github.com/romilly/brain-levers
# brain-levers-private: no README no GitHub
# brain-tools: no README no GitHub
# breadboarder: /home/romilly/git/active/breadboarder/README.md https://github.com/romilly/breadboarder
# browser-use-tests: no README no GitHub
# btb: no README no GitHub
# build-a-brain: /home/romilly/git/active/build-a-brain/README.md https://github.com/romilly/build-a-brain
# c-and-cython: no README no GitHub
# ce-glossary: /home/romilly/git/active/ce-glossary/README.md no GitHub
# cerebras-game: no README no GitHub
# chaining-agents: /home/romilly/git/active/chaining-agents/README.md https://github.com/romilly/chaining-agents
# chips-private: no README https://github.com/romilly/chips-private
# chrome-selection-saver: no README no GitHub
# chrome_extensions: /home/romilly/git/active/chrome_extensions/README.md no GitHub
# climate: /home/romilly/git/active/climate/README.md no GitHub
# cline-spike: no README no GitHub
# codon_spike: /home/romilly/git/active/codon_spike/README.md no GitHub
# companies-house-experiment: no README no GitHub
# compare-temperatures: /home/romilly/git/active/compare-temperatures/README.md https://github.com/romilly/compare-temperatures
# computational_neuroscience: /home/romilly/git/active/computational_neuroscience/README.md no GitHub
# conceptnet: /home/romilly/git/active/conceptnet/README.md no GitHub
# concordance: no README no GitHub
# course-creation-tools: /home/romilly/git/active/course-creation-tools/README.md https://github.com/romilly/course-creation-tools
# course_platform_clean: /home/romilly/git/active/course_platform_clean/README.md https://github.com/romilly/course_platform_clean
# crew: no README https://github.com/romilly/crew
# cuda-by-example: no README no GitHub
# cytoscape-spike: no README no GitHub
# dbpedia: /home/romilly/git/active/dbpedia/README.md no GitHub
# deepnote-experiments: /home/romilly/git/active/deepnote-experiments/README.md no GitHub
# deepseek-experiments: no README no GitHub
# distributive-rounding: /home/romilly/git/active/distributive-rounding/README.md no GitHub
# django_lms: /home/romilly/git/active/django_lms/README.md https://github.com/romilly/django_lms
# doc2course: no README no GitHub
# document_tree: /home/romilly/git/active/document_tree/README.md no GitHub
# dolly-spike: /home/romilly/git/active/dolly-spike/README.md no GitHub
# dp_cap: /home/romilly/git/active/dp_cap/README.md no GitHub
# dspy-experiments: /home/romilly/git/active/dspy-experiments/README.md no GitHub
# dynamic-store: no README no GitHub
# ecoacoustics: no README no GitHub
# eutopia: no README no GitHub
# evolution-course: no README no GitHub
# exercise_app: /home/romilly/git/active/exercise_app/README.md no GitHub
# explorer-hat: /home/romilly/git/active/explorer-hat/README.md https://github.com/romilly/explorer-hat
# explorer-hat-examples: /home/romilly/git/active/explorer-hat-examples/README.md https://github.com/romilly/explorer-hat-examples
# fast_index: no README no GitHub
# filestore: no README no GitHub
# filesystem: /home/romilly/git/active/filesystem/README.md no GitHub
# finance: no README https://github.com/romilly/finance
# fine-tuning: /home/romilly/git/active/fine-tuning/README.md https://github.com/romilly/fine-tuning
# finetuning: /home/romilly/git/active/finetuning/README.md no GitHub
# flask-test: /home/romilly/git/active/flask-test/README.md no GitHub
# flaskProject: no README no GitHub
# flomatic: /home/romilly/git/active/flomatic/README.md https://github.com/romilly/flomatic
# flowcharting: no README no GitHub
# fonny: /home/romilly/git/active/fonny/README.md https://github.com/romilly/fonny
# fp2md: /home/romilly/git/active/fp2md/README.md https://github.com/romilly/fp2md
# fr-lazydoro: no README https://github.com/romilly/fr-lazydoro
# frag: no README no GitHub
# freeplane-and-yaml: /home/romilly/git/active/freeplane-and-yaml/README.md https://github.com/romilly/freeplane-and-yaml
# friends-and-family: no README https://github.com/romilly/friends-and-family
# fuyu-spike: no README no GitHub
# galactic-unicorn: /home/romilly/git/active/galactic-unicorn/README.md https://github.com/romilly/galactic-unicorn
# ghost-publishing: no README https://github.com/romilly/ghost-publishing
# github-project-checklist: /home/romilly/git/active/github-project-checklist/README.md https://github.com/romilly/github-project-checklist
# github_star_tracker: /home/romilly/git/active/github_star_tracker/README.md https://github.com/romilly/github_star_tracker
# gmail_reader: no README no GitHub
# gpt-convo-reader: /home/romilly/git/active/gpt-convo-reader/README.md https://github.com/romilly/gpt-convo-reader
# gpt-pew-private: no README no GitHub
# gui-automation: /home/romilly/git/active/gui-automation/README.md https://github.com/romilly/freeplane-gui-automation
# health: no README no GitHub
# heat-energy: no README no GitHub
# heimer-tools: /home/romilly/git/active/heimer-tools/README.md https://github.com/romilly/heimer-tools
# helixnet: no README no GitHub
# hex-goos-crew: no README no GitHub
# hexagonal-tic-tac-toe: /home/romilly/git/active/hexagonal-tic-tac-toe/README.md no GitHub
# hexapawn: no README no GitHub
# hexapawn-pi: no README https://github.com/romilly/hexapawn-pi
# hf-embedding-cache-dir: no README no GitHub
# ii-microservice: no README https://github.com/romilly/ii-microservice
# image_pusher: /home/romilly/git/active/image_pusher/README.md https://github.com/romilly/image_pusher
# inequality: /home/romilly/git/active/inequality/README.md https://github.com/romilly/inequality
# info-products: no README https://github.com/romilly/info-products
# infrastructure: /home/romilly/git/active/infrastructure/README.md no GitHub
# ingress: no README no GitHub
# jax-spike: no README no GitHub
# jetson-xavier: no README no GitHub
# jupyter-ai-experiments: /home/romilly/git/active/jupyter-ai-experiments/README.md no GitHub
# justin-judd: no README no GitHub
# kew-pd: /home/romilly/git/active/kew-pd/README.md https://github.com/romilly/kew-pd
# keybot: /home/romilly/git/active/keybot/README.md no GitHub
# knowledge-exchange: no README no GitHub
# kw-pet-old: /home/romilly/git/active/kw-pet-old/README.md https://github.com/romilly/kw-pet
# lamini-experiments: /home/romilly/git/active/lamini-experiments/README.md https://github.com/romilly/lamini-experiments
# lang_chain_spike: /home/romilly/git/active/lang_chain_spike/README.md no GitHub
# langchain-academy: /home/romilly/git/active/langchain-academy/README.md https://github.com/langchain-ai/langchain-academy
# langchain_x: no README no GitHub
# latin: /home/romilly/git/active/latin/README.md no GitHub
# lean4: /home/romilly/git/active/lean4/README.md no GitHub
# leann-experiments: /home/romilly/git/active/leann-experiments/README.md no GitHub
# learn-lia: no README no GitHub
# learning-to-program-exercises: no README no GitHub
# lis.py: /home/romilly/git/active/lis.py/README.md no GitHub
# llama-cpp-python: /home/romilly/git/active/llama-cpp-python/README.md https://github.com/romilly/llama-cpp-python
# llama2_cpp_python_subprocess: /home/romilly/git/active/llama2_cpp_python_subprocess/README.md https://github.com/romilly/llama2_cpp_python_subprocess
# llama2_python_cublas: /home/romilly/git/active/llama2_python_cublas/README.md no GitHub
# llm-bench: /home/romilly/git/active/llm-bench/README.md https://github.com/romilly/llm-bench
# llm-experiments: no README no GitHub
# llm-leaderboards: no README no GitHub
# llmware_experiments: no README no GitHub
# lms-emerge: no README no GitHub
# lms-markua: no README no GitHub
# lms-ng: /home/romilly/git/active/lms-ng/README.md https://github.com/romilly/lms-ng
# lms-pdf-reader: /home/romilly/git/active/lms-pdf-reader/README.md no GitHub
# local-pypiserver: /home/romilly/git/active/local-pypiserver/README.md no GitHub
# logseq-personal: /home/romilly/git/active/logseq-personal/README.md https://github.com/romilly/logseq-personal
# logseq-tools: /home/romilly/git/active/logseq-tools/README.md https://github.com/romilly/logseq-tools
# lt-newell-and-simon: no README no GitHub
# manim_tools: no README no GitHub
# map-templates: /home/romilly/git/active/map-templates/README.md https://github.com/romilly/map-templates
# mark-watson-langchain: /home/romilly/git/active/mark-watson-langchain/README.md no GitHub
# market-research: no README no GitHub
# master-project-electronics: no README no GitHub
# mastodon_helper: no README https://github.com/romilly/mastodon_helper
# math-ocr: no README no GitHub
# maths: no README https://github.com/romilly/maths
# medium-publishing: no README no GitHub
# medium_access: /home/romilly/git/active/medium_access/README.md no GitHub
# mermaid-mint: /home/romilly/git/active/mermaid-mint/README.md https://github.com/romilly/mermaid-mint
# microplot: /home/romilly/git/active/microplot/README.md https://github.com/romilly/microplot
# microplot-private: no README https://github.com/romilly/microplot-private
# migrate-rareblog: no README no GitHub
# minaurac: no README no GitHub
# mindmap-tools: no README no GitHub
# mistral-fine-tuning: no README no GitHub
# mistral-planner: no README https://github.com/romilly/mistral-planner
# mistral_api: no README no GitHub
# mmap2mm: no README no GitHub
# mongo-atlas: no README no GitHub
# mooc-talk: no README https://github.com/romilly/mooc-talk
# mp_installer: /home/romilly/git/active/mp_installer/README.md https://github.com/romilly/mp_installer
# msc: /home/romilly/git/active/msc/README.md https://github.com/romilly/msc
# mujoco-experiments: no README no GitHub
# my-12-favourite-problems: no README no GitHub
# network_research: no README no GitHub
# neurips2023: no README no GitHub
# neuron-animation: /home/romilly/git/active/neuron-animation/README.md https://github.com/romilly/neuron-animation
# niche: no README no GitHub
# nlp4marketing: no README no GitHub
# o-x-o: /home/romilly/git/active/o-x-o/README.md https://github.com/romilly/o-x-o
# obsidian-spike: no README no GitHub
# ollama-experiments: no README no GitHub
# ollama-kit: /home/romilly/git/active/ollama-kit/README.md https://github.com/romilly/ollama-kit
# ollama-oracle: /home/romilly/git/active/ollama-oracle/README.md https://github.com/romilly/ollama-oracle
# openchat: no README no GitHub
# openscad-experiments: no README no GitHub
# oxo: no README https://github.com/romilly/oxo
# paddleocr-spike: no README no GitHub
# paperchase-skno: no README https://github.com/romilly/paperchase-skno
# paperscraper-librarian: /home/romilly/git/active/paperscraper-librarian/README.md no GitHub
# parts-bins: no README no GitHub
# pdf-management: no README https://github.com/romilly/pdf-management
# pdp-connectionist-resources: no README no GitHub
# peltier: no README no GitHub
# perplexity_ai_api_spikes: no README no GitHub
# pico-code: /home/romilly/git/active/pico-code/README.md https://github.com/romilly/pico-code
# pico-fig-forth: no README no GitHub
# pico-forth-from-claude: /home/romilly/git/active/pico-forth-from-claude/README.md https://github.com/romilly/pico-forth-from-claude
# pico-hid: no README no GitHub
# pimoroni-booklet: /home/romilly/git/active/pimoroni-booklet/README.md https://github.com/romilly/pimoroni-booklet
# pimoroni-booklet-drafts: no README https://github.com/romilly/pimoroni-booklet-drafts
# pimoroni-booklet-private: /home/romilly/git/active/pimoroni-booklet-private/README.md https://github.com/romilly/pimoroni-booklet-private
# pimoroni-explorer-code: /home/romilly/git/active/pimoroni-explorer-code/README.md no GitHub
# pimoscope: no README no GitHub
# pintercom: no README https://github.com/romilly/pintercom
# pip: /home/romilly/git/active/pip/README.md https://github.com/romilly/pip
# pip2: /home/romilly/git/active/pip2/README.md https://github.com/romilly/pip2
# planning: /home/romilly/git/active/planning/README.md https://github.com/romilly/planning
# pm-aid: /home/romilly/git/active/pm-aid/README.md https://github.com/romilly/pm-aid
# presentation-writer: no README no GitHub
# prioretize_via_gpt: no README https://github.com/romilly/prioretize_via_gpt
# project-database: /home/romilly/git/active/project-database/README.md no GitHub
# project_management: /home/romilly/git/active/project_management/README.md no GitHub
# prostate_radiotherapy: no README https://github.com/romilly/prostate_radiotherapy
# py-bpmn: /home/romilly/git/active/py-bpmn/README.md no GitHub
# pyactr-spike: no README no GitHub
# pygmy17: no README no GitHub
# pymap: no README no GitHub
# pymex: no README https://github.com/romilly/pymex
# pyscript-spikes: no README no GitHub
# python-ast: no README no GitHub
# python-cuda: no README no GitHub
# python-explorer: no README https://github.com/romilly/python-explorer
# python-tutor: no README no GitHub
# pythonProject: no README no GitHub
# pytrace-eval: /home/romilly/git/active/pytrace-eval/README.md no GitHub
# quip-sharp: /home/romilly/git/active/quip-sharp/README.md https://github.com/Cornell-RelaxML/quip-sharp
# quip_sharp_experiments: no README no GitHub
# rareblog-examples: /home/romilly/git/active/rareblog-examples/README.md https://github.com/romilly/rareblog-examples
# rareschool: no README https://github.com/romilly/rareschool
# rareschool-private: no README https://github.com/romilly/rareschool-private
# rdf_lib: no README no GitHub
# redpajama: no README no GitHub
# redpajama.cpp: /home/romilly/git/active/redpajama.cpp/README.md https://github.com/romilly/redpajama.cpp
# reinforcement_learning: no README no GitHub
# retirement-move: /home/romilly/git/active/retirement-move/README.md https://github.com/romilly/retirement-move
# reveal: no README no GitHub
# rlm: /home/romilly/git/active/rlm/README.md https://github.com/alexzhang13/rlm
# rocnet: no README no GitHub
# rss: no README no GitHub
# rwkv: no README no GitHub
# rwkv.cpp: /home/romilly/git/active/rwkv.cpp/README.md https://github.com/romilly/rwkv.cpp
# rwkv.cpp-cublas: /home/romilly/git/active/rwkv.cpp-cublas/README.md https://github.com/saharNooby/rwkv.cpp
# s2-crew-tool: no README no GitHub
# s2ag-citation-graph: no README no GitHub
# s2ag-corpus: /home/romilly/git/active/s2ag-corpus/README.md https://github.com/romilly/s2ag-corpus
# s2agr: /home/romilly/git/active/s2agr/README.md https://github.com/romilly/s2agr
# s2agr-spacy: no README no GitHub
# s2ai2: /home/romilly/git/active/s2ai2/README.md https://github.com/romilly/s2ai2
# s2archive: no README https://github.com/romilly/s2ag
# schematix: no README no GitHub
# scrcap: no README no GitHub
# second_brain_llamaindex: /home/romilly/git/active/second_brain_llamaindex/README.md no GitHub
# semantic-kernel-spike: no README no GitHub
# semantic_RAG: /home/romilly/git/active/semantic_RAG/README.md no GitHub
# semanticscholar: /home/romilly/git/active/semanticscholar/README.md https://github.com/romilly/semanticscholar
# servus-orig: /home/romilly/git/active/servus-orig/README.md https://github.com/romilly/servus
# seven-decades: /home/romilly/git/active/seven-decades/README.md no GitHub
# sh1107-lcd: no README no GitHub
# shot-scraper-experiments: /home/romilly/git/active/shot-scraper-experiments/README.md no GitHub
# similarity-graph-traversal-semantic-rag-research: /home/romilly/git/active/similarity-graph-traversal-semantic-rag-research/README.md https://github.com/romilly/similarity-graph-traversal-semantic-rag-research
# simple-scholar: no README https://github.com/romilly/simple-scholar
# simple-scholar-backup: no README https://github.com/romilly/simple-scholar
# skno-sna: /home/romilly/git/active/skno-sna/README.md https://github.com/romilly/skno-sna
# skno-spikes: /home/romilly/git/active/skno-spikes/README.md no GitHub
# smalltalk-v: no README no GitHub
# smolagents-spike: no README no GitHub
# snake: no README no GitHub
# spear-gpt: /home/romilly/git/active/spear-gpt/README.md https://github.com/romilly/spear-gpt
# spear-react: no README https://github.com/romilly/spear-react
# spear-svelte: no README no GitHub
# speech_recognition: no README no GitHub
# spiking-jax: /home/romilly/git/active/spiking-jax/README.md https://github.com/romilly/spiking-jax
# ssd-1b-spike: no README no GitHub
# start-apl: /home/romilly/git/active/start-apl/README.md https://github.com/romilly/start-apl
# starting-pico-w: /home/romilly/git/active/starting-pico-w/README.md https://github.com/romilly/starting-pico-w
# starting-pico-w-private: /home/romilly/git/active/starting-pico-w-private/README.md https://github.com/romilly/starting-pico-w-private
# streamlit_spikes: /home/romilly/git/active/streamlit_spikes/README.md https://github.com/romilly/streamlit_spikes
# substack: /home/romilly/git/active/substack/README.md https://github.com/romilly/substack
# svg: /home/romilly/git/active/svg/README.md https://github.com/romilly/svg
# t3-python: /home/romilly/git/active/t3-python/README.md no GitHub
# talent_vs_luck: no README no GitHub
# tdd-lazydoro: /home/romilly/git/active/tdd-lazydoro/README.md https://github.com/romilly/tdd-lazydoro
# tech-talks-private: /home/romilly/git/active/tech-talks-private/README.md https://github.com/romilly/tech-talks-private
# technical-talks: /home/romilly/git/active/technical-talks/README.md https://github.com/romilly/technical-talks
# test-project-123: /home/romilly/git/active/test-project-123/README.md no GitHub
# testing-guizero-apps: /home/romilly/git/active/testing-guizero-apps/README.md https://github.com/romilly/testing-guizero-apps
# textual-experiments: /home/romilly/git/active/textual-experiments/README.md no GitHub
# tidy-up: no README no GitHub
# tiny-4wd: /home/romilly/git/active/tiny-4wd/README.md no GitHub
# tools: /home/romilly/git/active/tools/README.md https://github.com/romilly/tools
# transcriber: no README no GitHub
# transforming-education: no README no GitHub
# triangle_test: no README no GitHub
# tvl: no README no GitHub
# typesense_spike: no README no GitHub
# vLLM-experiments: no README no GitHub
# venn-generator: no README no GitHub
# video-factory: no README no GitHub
# visual-thinking: no README no GitHub
# wardley-challenge: /home/romilly/git/active/wardley-challenge/README.md https://github.com/romilly/wardley-challenge
# well-being: no README no GitHub
# wesnoth-spike: /home/romilly/git/active/wesnoth-spike/README.md no GitHub
# ws-spike: no README no GitHub
# yard-sale: /home/romilly/git/active/yard-sale/README.md https://github.com/romilly/yard-sale
# zepto-forth: no README no GitHub
# zero-web: no README https://github.com/romilly/zero-web
# zotero-web: /home/romilly/git/active/zotero-web/README.md no GitHub
